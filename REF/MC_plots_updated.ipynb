# %%
from pathlib import Path

import numpy as np
import matplotlib.colors as mcolors
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from scipy.interpolate import interp1d
from scipy.optimize import curve_fit

DATA_DIR = Path("WKB_QCD_data")
DEG_DIR = Path("Data")
PLOT_DIR = Path("Plots/NSC_pert/ALP_perturbations/QCD_axion")
PLOT_DIR.mkdir(parents=True, exist_ok=True)

plt.rcParams.update({
    "pdf.fonttype": 42,
    "text.usetex": True,
    "text.latex.preamble": r"\usepackage{amsmath, amssymb}",
    "font.family": "serif",
    "font.size": 16,
    "axes.labelsize": 20,
    "axes.titlesize": 18,
    "legend.fontsize": 14,
    "xtick.labelsize": 16,
    "ytick.labelsize": 16,
})

def load_degrees(path):
    table = np.loadtxt(path)
    return interp1d(table[:, 0], table[:, 1], bounds_error=False, fill_value="extrapolate")

gstar = load_degrees(DEG_DIR / "geffdhs.dat")
gstars = load_degrees(DEG_DIR / "heffdhs.dat")
dgstar = load_degrees(DEG_DIR / "geffderivdhs.dat")
dgstars = load_degrees(DEG_DIR / "heffderivdhs.dat")

MC_FILES = [
    DATA_DIR / "qcd_mc.npz",
    DATA_DIR / "qcd_mc_extra.npz",
]

def load_mc_files(files):
    keys = [
        "kappas", "delta_a_eq", "x_eq", "k_J_eq", "k_RH",
        "Tend", "MA0", "R_RH", "k_osc", "k_L"
    ]

    chunks = {key: [] for key in keys}

    for file in files:
        if not file.exists():
            continue

        with np.load(file) as data:
            for key in keys:
                chunks[key].append(data[key])

    out = {}

    for key in keys:
        out[key] = np.concatenate(chunks[key], axis=0)

    return out

data = load_mc_files(MC_FILES)

kappas_all = data["kappas"]
delta_a_eq_all = data["delta_a_eq"]
x_eq_all = data["x_eq"]
k_J_eq_all = data["k_J_eq"]  / 4.5
k_RH_all = data["k_RH"]
Tend_all = data["Tend"]
MA0_all = data["MA0"]
R_RH_all = data["R_RH"]
k_osc_all = data["k_osc"]
k_L_all = data["k_L"]

kappa_nls = []

for kps, dlt, kj in zip(kappas_all, delta_a_eq_all, k_J_eq_all):
    crossing = np.where((dlt[:-1] < 1.0) & (dlt[1:] > 1.0))[0]

    if len(crossing) == 0:
        kappa_nls.append(np.nan)
        continue

    idx = crossing[0]
    k1, k2 = kps[idx], kps[idx + 1]
    y1, y2 = dlt[idx], dlt[idx + 1]

    log_k = np.log10(k1) + (np.log10(k2) - np.log10(k1)) * (0.0 - np.log10(y1)) / (np.log10(y2) - np.log10(y1))
    k_val = 10.0**log_k

    kappa_nls.append(k_val if k_val < kj else np.nan)

kappa_nls = np.asarray(kappa_nls)

sort_idx = np.argsort(MA0_all)

MA0_s = MA0_all[sort_idx]
Tend_s = Tend_all[sort_idx]
kappas_s = kappas_all[sort_idx]
delta_a_eq_s = delta_a_eq_all[sort_idx]
k_J_eq_s = k_J_eq_all[sort_idx]
x_eq_s = x_eq_all[sort_idx]
k_RH_s = k_RH_all[sort_idx]
R_RH_s = R_RH_all[sort_idx]
k_osc_s = k_osc_all[sort_idx]
k_L_s = k_L_all[sort_idx]
kappa_nls_s = kappa_nls[sort_idx]

kappa_osc_s = k_osc_s / k_RH_s
kappa_L_s = k_L_s / k_RH_s

Teq_ev = 0.79
Teq_gev = Teq_ev * 1e-9
g_star_eq = 3.36
rho_eq = g_star_eq * (np.pi**2 / 30.0) * Teq_gev**4 * 0.8
M_solar_GeV = 1.115e57

M_mc_solar_s = np.full_like(MA0_s, np.nan)
valid_m = np.isfinite(kappa_nls_s)

k_nls_phys = kappa_nls_s[valid_m] * k_RH_s[valid_m]
r_nl_s = x_eq_s[valid_m] * R_RH_s[valid_m] * np.pi / (2.0 * k_nls_phys)
M_mc_s = (8.0 * np.pi / 3.0) * rho_eq * r_nl_s**3
M_mc_solar_s[valid_m] = M_mc_s / M_solar_GeV

# %%
valid = ~np.isnan(kappa_nls_s)
M_v = MA0_s[valid] * 1e9
T_v = Tend_s[valid] * 1e3
K_v = kappa_nls_s[valid]

fig, ax1 = plt.subplots(figsize=(9, 6))

ax1.plot(M_v, K_v, color='blue', lw=2.5)

ax1.set_xscale('log')
ax1.set_yscale('log')
ax1.set_xlabel(r'$m_{a,0}$ [eV]')
ax1.set_ylabel(r'$\kappa_{nl}$')
ax1.grid(True, which="both", ls="--", alpha=0.3)

ax2 = ax1.twiny()
ax2.set_xscale('log')
ax2.set_xlim(ax1.get_xlim())

n_ticks = 6
idx_ticks = np.linspace(0, len(M_v)-1, n_ticks, dtype=int)
ax2.set_xticks(M_v[idx_ticks])
ax2.set_xticklabels([f"{T_v[i]:.1f}" for i in idx_ticks])
ax2.set_xlabel(r'$T_{RH}$ [MeV]')

plt.tight_layout()
plt.show()

# %%
kappa_vals = np.asarray(kappas_s[0], dtype=float)
ma0_vals = np.asarray(MA0_s * 1e9, dtype=float)
delta_eq_vals = np.asarray(delta_a_eq_s, dtype=float)

kappa_grid, ma0_grid = np.meshgrid(kappa_vals, ma0_vals)

delta_positive = delta_eq_vals[np.isfinite(delta_eq_vals) & (delta_eq_vals > 0.0)]
delta_min = delta_positive.min()
delta_max = delta_positive.max()

delta_eq_masked = np.ma.masked_where(~np.isfinite(delta_eq_vals) | (delta_eq_vals <= 0.0), delta_eq_vals)

valid_idx = np.where(np.isfinite(kappa_nls_s) & np.isfinite(k_J_eq_s) & np.isfinite(ma0_vals) & (kappa_nls_s > 0.0) & (k_J_eq_s > 0.0) & (ma0_vals > 0.0))[0]

i1, i2 = valid_idx[-2], valid_idx[-1]

log_m1, log_m2 = np.log10(ma0_vals[i1]), np.log10(ma0_vals[i2])
log_knl1, log_knl2 = np.log10(kappa_nls_s[i1]), np.log10(kappa_nls_s[i2])
log_kj1, log_kj2 = np.log10(k_J_eq_s[i1]), np.log10(k_J_eq_s[i2])

slope_knl = (log_knl2 - log_knl1) / (log_m2 - log_m1)
slope_kj = (log_kj2 - log_kj1) / (log_m2 - log_m1)

log_m_cross = log_m1 + (log_kj1 - log_knl1) / (slope_knl - slope_kj)
log_k_cross = log_knl1 + slope_knl * (log_m_cross - log_m1)

kappa_nl_plot = np.append(kappa_nls_s[valid_idx], 10.0**log_k_cross)
ma0_nl_plot = np.append(ma0_vals[valid_idx], 10.0**log_m_cross)

fig, ax = plt.subplots(figsize=(8, 6))

norm = mcolors.LogNorm(vmin=delta_min, vmax=delta_max)
levels = np.logspace(np.log10(delta_min), np.log10(delta_max), 18)

contour = ax.contourf(kappa_grid, ma0_grid, delta_eq_masked, levels=levels, norm=norm, cmap="plasma")

def log_formatter(val, pos):
    if val <= 0.0 or not np.isfinite(val):
        return ""
    if np.isclose(val, 1.0):
        return r"$1$"
    if np.isclose(val, 10.0):
        return r"$10$"
    exp = int(np.floor(np.log10(val)))
    coeff = val / 10.0**exp
    if np.isclose(coeff, 1.0):
        return rf"$10^{{{exp}}}$"
    return rf"${coeff:g} \times 10^{{{exp}}}$"

cbar = fig.colorbar(contour, ax=ax, pad=0.18)
cbar.ax.yaxis.set_major_locator(ticker.LogLocator(base=10.0, numticks=10))
cbar.ax.yaxis.set_major_formatter(ticker.FuncFormatter(log_formatter))
cbar.ax.yaxis.set_minor_locator(ticker.NullLocator())
cbar.ax.yaxis.set_minor_formatter(ticker.NullFormatter())
cbar.set_label(r"$|\delta_a(\kappa, x_\mathrm{eq})|$")

ax.plot(kappa_nl_plot, ma0_nl_plot, color="black", ls="-", lw=2.5, label=r"$|\delta_a|=1$")
ax.plot(k_J_eq_s, ma0_vals, color="#117733", ls="--", lw=2.5, alpha=0.9, label=r"$\kappa_J$")
ax.plot(kappa_osc_s, ma0_vals, color="white", ls=":", lw=2.5, alpha=0.9, label=r"$\kappa_{\mathrm{osc}}$")
ax.plot(kappa_L_s, ma0_vals, color="#00FFFF", ls="-.", lw=2.5, alpha=0.9, label=r"$\kappa_\Lambda$")

ax.set_xscale("log")
ax.set_yscale("log")
ax.set_xlim(kappa_vals.min(), kappa_vals.max())
ax.set_ylim(ma0_vals.min(), ma0_vals.max())
ax.set_xlabel(r"$\kappa$")
ax.set_ylabel(r"$m_{a,0}$ [eV]")
ax.legend(loc="upper left")

ax_temp = ax.twinx()
ax_temp.set_yscale("log")
ax_temp.set_ylim(ax.get_ylim())

trh_vals = np.asarray(Tend_s * 1e3, dtype=float)
sort_idx = np.argsort(trh_vals)

trh_sorted = trh_vals[sort_idx]
ma0_sorted = ma0_vals[sort_idx]

valid_temp = np.isfinite(trh_sorted) & np.isfinite(ma0_sorted) & (trh_sorted > 0.0) & (ma0_sorted > 0.0)
trh_sorted = trh_sorted[valid_temp]
ma0_sorted = ma0_sorted[valid_temp]

trh_ticks = np.array([5, 10, 20, 50, 100, 200, 300], dtype=float)
trh_ticks = trh_ticks[(trh_ticks >= trh_sorted.min()) & (trh_ticks <= trh_sorted.max())]

tick_pos = 10.0**np.interp(np.log10(trh_ticks), np.log10(trh_sorted), np.log10(ma0_sorted))

ax_temp.yaxis.set_major_locator(ticker.FixedLocator(tick_pos))
ax_temp.yaxis.set_major_formatter(ticker.FixedFormatter([rf"${int(t)}$" for t in trh_ticks]))
ax_temp.yaxis.set_minor_locator(ticker.NullLocator())
ax_temp.yaxis.set_minor_formatter(ticker.NullFormatter())
ax_temp.tick_params(axis="y", which="major", direction="out", length=5, pad=4)
ax_temp.tick_params(axis="y", which="minor", length=0)
ax_temp.set_ylabel(r"$T_\mathrm{RH}$ [MeV]")

fig.subplots_adjust(left=0.13, right=0.78, bottom=0.13, top=0.95)
fig.savefig(PLOT_DIR / "delta_a_qcd_eq.pdf", dpi=300)
plt.show()

# %%
valid = ~np.isnan(M_mc_solar_s)
M_v = MA0_s[valid] * 1e9 
T_v = Tend_s[valid] * 1e3
Mc_v = M_mc_solar_s[valid]

fig, ax1 = plt.subplots(figsize=(8, 6))

ax1.plot(M_v, Mc_v, color='blue', lw=2.5)

log_t = np.log10(T_v)
log_m = np.log10(M_v)
sort_t = np.argsort(log_t)
log_m_150 = np.interp(np.log10(150.0), log_t[sort_t], log_m[sort_t])
m_150 = 10**log_m_150

log_m_100 = np.interp(np.log10(100.0), log_t[sort_t], log_m[sort_t])
m_100 = 10**log_m_100

ax1.axvline(m_150, color="#FFC107", ls='--', lw=2.5, zorder=0)

y_mid = 10**((np.log10(Mc_v.max()) + np.log10(Mc_v.min())) / 2.0)
ax1.text(m_150 * 0.95, y_mid*5.0, r'$T_{RH} = 150\,$MeV', color="#000000FF", rotation=90, va='center', ha='right', fontsize=18)


ax1.set_xscale('log')
ax1.set_yscale('log')
ax1.set_xlim(M_v.min() * 0.99, M_v.max() * 1.01)
ax1.set_ylim(Mc_v.min() * 0.99, Mc_v.max() * 1.01)
ax1.set_xlabel(r'$m_{a,0}$ [eV]')
ax1.set_ylabel(r'$M_{c} \ [M_\odot]$')

ax2 = ax1.twiny()
ax2.set_xscale('log')
ax2.set_xlim(ax1.get_xlim())

n_ticks = 8
idx_ticks = np.linspace(0, len(M_v)-1, n_ticks, dtype=int)
ax2.set_xticks(M_v[idx_ticks])
ax2.set_xticklabels([f"{T_v[i]:.1f}" for i in idx_ticks])
ax2.set_xlabel(r'$T_{RH}$ [MeV]')

#plt.savefig("QCD_axion_eq.pdf", dpi=300)
plt.tight_layout()
plt.show()

# %%
def _mass(T, Tl, b, ma0):
    T_arr = np.asarray(T, dtype=float)
    if b == 0:
        return np.full_like(T_arr, ma0, dtype=float)
    return np.where(T_arr <= Tl, ma0, ma0 * (Tl / T_arr) ** b)

MA0_base = 3.58e-7
T_RH_plot = np.logspace(np.log10(0.003), np.log10(0.320), 100)
theta_i = 1

ma_trh_plot = MA0_base * (gstar(T_RH_plot)**0.5 / gstars(T_RH_plot)**(2.0 / 3.0)) * (T_RH_plot / 0.150)**(4.0 / 3.0) * theta_i**(4.0 / 3.0)

MA_MIN = ma_trh_plot[0]
MA_Max = ma_trh_plot[-1]

# %%
theta_ini = 1
MA0_base = 3.58e-7

T_grid_gev = np.logspace(np.log10(0.003), np.log10(0.320), 100)
T_grid_mev = 1e3 * T_grid_gev

ma_grid = MA0_base * (gstar(T_grid_gev)**0.5 / gstars(T_grid_gev)**(2.0 / 3.0)) * (T_grid_gev / 0.150)**(4.0 / 3.0) * theta_ini**(4.0 / 3.0)
ma_min, ma_max = ma_grid[0], ma_grid[-1]

ma_data = np.asarray(M_v, dtype=float)
mc_data = np.asarray(Mc_v, dtype=float)
T_data = np.asarray(T_v, dtype=float)

mask = np.isfinite(ma_data) & np.isfinite(mc_data) & np.isfinite(T_data) & (ma_data > 0.0) & (mc_data > 0.0) & (T_data > 0.0)
ma_data, mc_data, T_data = ma_data[mask], mc_data[mask], T_data[mask]

if np.nanmax(T_data) < 1.0:
    T_data *= 1000.0

idx = np.argsort(ma_data)
ma_data, mc_data, T_data = ma_data[idx], mc_data[idx], T_data[idx]

def low_model(T, A):
    return A * (T / 150.0)**(-3.0)

def power_model(T, A, p):
    return A * (T / 150.0)**p

low_mask = (T_data >= 15.0) & (T_data <= 35.0)
mid_mask = (T_data > 35.0) & (T_data <= 150.0)
high_mask = T_data >= 150.0

low_pars, _ = curve_fit(low_model, T_data[low_mask], mc_data[low_mask], p0=[1e-6], bounds=([1e-15], [1e-1]), sigma=mc_data[low_mask], absolute_sigma=False, maxfev=10000)
mid_pars, _ = curve_fit(power_model, T_data[mid_mask], mc_data[mid_mask], p0=[1e-6, -3.0], bounds=([1e-15, -20.0], [1e-1, 10.0]), sigma=mc_data[mid_mask], absolute_sigma=False, maxfev=10000)
high_pars, _ = curve_fit(power_model, T_data[high_mask], mc_data[high_mask], p0=[1e-6, -3.0], bounds=([1e-15, -15.0], [1e-1, 10.0]), sigma=mc_data[high_mask], absolute_sigma=False, maxfev=10000)

low_A, low_p = low_pars[0], -3.0
mid_A, mid_p = 1.50e-11 * 0.8, -2.0 / 3.0
high_p = high_pars[1]

T_anchor = np.interp(ma_data[-1], ma_grid, T_grid_mev)
high_A = mc_data[-1] / (T_anchor / 150.0)**high_p

low_curve = low_A * (T_grid_mev / 150.0)**low_p
mid_curve = mid_A * (T_grid_mev / 150.0)**mid_p
high_curve = high_A * (T_grid_mev / 150.0)**high_p

colors = ["#4477AA", "#AF4658", "#DDCC77", "#117733"]

fig, ax = plt.subplots(figsize=(9, 6))

ax.plot(ma_data, mc_data, color="black", lw=7, zorder=1)
ax.plot(ma_grid, low_curve, color=colors[0], ls=":", lw=1.5, zorder=2)
ax.plot(ma_grid, mid_curve, color=colors[1], ls="--", lw=1.5, zorder=2)
ax.plot(ma_grid, high_curve, color=colors[3], ls="-.", lw=1.5, zorder=2)

ax.set_xscale("log")
ax.set_yscale("log")
ax.set_xlim(ma_min, ma_max)
ax.set_ylim(mc_data.min() * 0.1, mc_data.max() * 5.0)

def add_label(ax, x, y, i, text, color, shift):
    i0 = max(0, i - 5)
    i1 = min(len(x) - 1, i + 5)

    dx = np.log10(x[i1]) - np.log10(x[i0])
    dy = np.log10(y[i1]) - np.log10(y[i0])
    ax_dx = np.log10(ax.get_xlim()[1]) - np.log10(ax.get_xlim()[0])
    ax_dy = np.log10(ax.get_ylim()[1]) - np.log10(ax.get_ylim()[0])

    angle = np.degrees(np.arctan2((dy / ax_dy) * 6.0, (dx / ax_dx) * 9.0))
    ax.text(x[i], y[i] * shift, text, color=color, rotation=angle, ha="center", va="bottom", clip_on=True)

i_low = np.argmin(np.abs(T_grid_mev - 25.0))
i_mid = np.argmin(np.abs(T_grid_mev - 75.0))
i_high = np.argmin(np.abs(T_grid_mev - 170.0))

add_label(ax, ma_grid / 2.0, low_curve * 2.2, i_low, r"$M_{\mathrm{mc}} \propto T_{\mathrm{RH}}^{-3}$", colors[0], 1.5)
add_label(ax, ma_grid / 8.0, mid_curve * 0.4, i_mid, fr"$M_{{\mathrm{{mc}}}} \propto T_{{\mathrm{{RH}}}}^{{{mid_p:.2f}}}$", colors[1], 1.5)
add_label(ax, ma_grid / 2.7, high_curve * 24.0, i_high, fr"$M_{{\mathrm{{mc}}}} \propto T_{{\mathrm{{RH}}}}^{{{high_p:.1f}}}$", colors[3], 2.0)

y_center = 10.0**(0.5 * (np.log10(ax.get_ylim()[0]) + np.log10(ax.get_ylim()[1])))
ma_data_min, ma_data_max = ma_data[0], ma_data[-1]

ax.axvspan(ma_min, ma_data_min, color="#AEC6CF", alpha=0.4, zorder=-1)
ax.text(ma_data_min * 0.95, y_center * 1e-1, r"$T_{\mathrm{RH}} < T_{\mathrm{BBN}}$", color="black", rotation=90, va="center", ha="right")

ax.axvspan(ma_data_max, ma_max, color="#C3B1E1", alpha=0.3, zorder=-1)
ax.text(ma_data_max * 1.05, y_center, r"$|\delta_a| < 1$", color="black", rotation=90, va="center", ha="left")

ax.set_xlabel(r"$m_{a,0}$ [eV]")
ax.set_ylabel(r"$M_{\mathrm{mc}}\,[M_\odot]$")

top_ax = ax.twiny()
top_ax.set_xscale("log")
top_ax.set_xlim(ax.get_xlim())

idx_T = np.argsort(T_grid_mev)
T_axis = np.asarray(T_grid_mev[idx_T], dtype=float)
ma_axis = np.asarray(ma_grid[idx_T], dtype=float)

axis_mask = np.isfinite(T_axis) & np.isfinite(ma_axis) & (T_axis > 0.0) & (ma_axis > 0.0)
T_axis, ma_axis = T_axis[axis_mask], ma_axis[axis_mask]

T_ticks = np.array([5, 10, 20, 50, 100, 150, 200], dtype=float)
T_ticks = T_ticks[(T_ticks >= T_axis.min()) & (T_ticks <= T_axis.max())]

tick_pos = 10.0**np.interp(np.log10(T_ticks), np.log10(T_axis), np.log10(ma_axis))

top_ax.xaxis.set_major_locator(ticker.FixedLocator(tick_pos))
top_ax.xaxis.set_major_formatter(ticker.FixedFormatter([rf"${int(T)}$" for T in T_ticks]))
top_ax.xaxis.set_minor_locator(ticker.NullLocator())
top_ax.xaxis.set_minor_formatter(ticker.NullFormatter())
top_ax.tick_params(axis="x", which="major", direction="out", length=5, pad=4)
top_ax.tick_params(axis="x", which="minor", length=0)
top_ax.set_xlabel(r"$T_{\mathrm{RH}}$ [MeV]")

fig.subplots_adjust(left=0.13, right=0.97, bottom=0.13, top=0.88)

fig.savefig(PLOT_DIR / "QCD_axion_eq_an.pdf", dpi=300)
plt.show()


print("low_A  =", low_A)
print("mid_A  =", mid_A)
print("high_A =", high_A)

print("low_A / 1e-11  =", low_A / 1e-11)
print("mid_A / 1e-11  =", mid_A / 1e-11)
print("high_A / 1e-11 =", high_A / 1e-11)
# Out:
# low_A  = 6.491255001961413e-13
# mid_A  = 1.2e-11
# high_A = 6.940537688830289e-12
# low_A / 1e-11  = 0.06491255001961413
# mid_A / 1e-11  = 1.2000000000000002
# high_A / 1e-11 = 0.6940537688830289
